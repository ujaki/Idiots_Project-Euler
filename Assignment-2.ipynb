# %% [markdown]
# ***
# # Problem 1

# %% [markdown]
# - 다음 6개의Expression에 대해 Evaluation 결과 값을 출력하고, 해당 결과가 나온 이유에 대해 설명하시오
#    - 1 and 2 and 3 and 4
#    - 1 or 2 or 3 or 4
#    - 1 and 2 or 3 and 4
#    - (1 and 2) or (3 and 4)
#    - 1 or 2 and 3 or 4
#    - (1 or 2) and (3 or 4)
# ***

# %% [markdown]
#  - 객체의 진리 값은 0 또는 빈 객체이면 거짓, 이외의 것은 참이다.
#  - 논리식의 계산 순서는 결과가 알려지는 시점까지만 계산되고 최종 계산 시점의 객체를 리턴한다.

# %%
1 and 2 and 3 and 4
# Out:
# 4

# %% [markdown]
# 설명 : 1, 2, 3, 4 모두 확인해야 되서 4개 모두 계산하므로 4가 최종 계산 위치라서 4가 리턴되어 4가 출력됩니다.

# %%
1 or 2 or 3 or 4
# Out:
# 1

# %% [markdown]
# 설명 : 1이 참이므로 더 이상 계산하지 않아도 참이므로 결과는 1입니다.

# %%
1 and 2 or 3 and 4
# Out:
# 2

# %% [markdown]
# 설명 : 1 and 2의 결과 최종 계산인 2가 리턴되고 2 or 3 and 4에서 2는 참이므로 or연산조건에 의해 최종결과는 참이므로 2가 출력됩니다.

# %%
(1 and 2) or (3 and 4)
# Out:
# 2

# %% [markdown]
# 설명 : 1 and 2의 결과 최종 계산인 2가 리턴되고 3 and 4는 4가 리턴되서 최종 계산은 2 or 4가 되는데 여기서 2가 참이므로  or연산조건에 의해 2가 출력됩니다.

# %%
1 or 2 and 3 or 4
# Out:
# 1

# %% [markdown]
# 설명 : 1 or 2 연산 결과 참이므로 1이 출력됩니다.

# %%
(1 or 2) and (3 or 4)
# Out:
# 3

# %% [markdown]
# 설명 : 가로 안에 있는 1 or 2의 값은 1이고 3 or 4는 3이므로 1 and 3은 최종 계산인 3이 출력됩니다.

# %% [markdown]
# ***
# # Problem 2

# %% [markdown]
# - 7/5, -7/5, -(7/5)의 결과를 확인하고 각각의 결과가 왜 그렇게 나오는 지 설명하시오
#   - [참고] 몫은 항상 음의 무한대 방향으로 round up (반올림) 된다는 점을 기억해야 함
# ***

# %%
print '7/5 : ',
print 7/5
print '-----------------------------'
print '-7/5 : ',
print -7/5
print '-----------------------------'
print '-(7/5) : ',
print -(7/5)
print '-----------------------------'
# Out:
# 7/5 :  1
# -----------------------------
# -7/5 :  -2
# -----------------------------
# -(7/5) :  -1
# -----------------------------

# %% [markdown]
# 설명
#     - 7/5는 양수이고 몫이 1임으로 1이 출력됩니다.
#     - -7/5는 단항 연산자(-)의 우선순위가 이항 연산자(/)의 우선순위보다 높으므로 -7를 5로 나누면 -1.--인데 파이썬에서 몫은 항상 음의 무한대 방향으로 반올림 됨으로 출력결과는 -2가 됩니다.
#     - -(7/5)는 가로안에 있는 연산부터 수행됨으로 7/5의 결과는 1, 이 결과에 - 연산을 수행하면 양수에서 음수로 바뀜으로 결과는 -1이 됩니다.

# %% [markdown]
# ***
# # Problem 3

# %% [markdown]
# - 키보드로 정수값을 입력 받고 그 값이 양수인지 음수인지를 비트 연산자를 이용하여 판단하는 프로그램을 작성하시오.
#   - [참고] 가장 왼쪽에 있는 비트가 0이면 양수이며, 1이면 음수이다.
# ***

# %%
for x in range(3):
    num = input("int : ") #정수 입력
    temp = ~num     #비트 반전
    if temp == -1: #0의 비트반전된 값은 -1임으로 
        print '0입니다.'
    elif num <= temp: #비트 반전된 정수가 입력한 정수보다 클때 음수이다.
        print "음수입니다." #정수 -1의 비트 반전은 0임으로 크거나 같다를 사용
    elif num > temp:
        print "양수입니다." #0은 정수로 출력
# Out:
# int : 0
# 0입니다.
# int : 1
# 양수입니다.
# int : -1
# 음수입니다.

# %% [markdown]
# - 설명 : 입력한 정수를 비트연산을 이용해서 음과 양의 판별은 비트 반전 연산인 ~ 을 이용하였습니다.
# - (1) temp 변수에 입력 받은 정수에 대한 비트 반전된 값을 입력합니다.
# - (2) 조건문을 이용하여 비트 반전된 정수가 입력한 정수 보다 클때 음수임으로 '음수입니다.'라고 출력합니다. 예를 들어 양수가 입력되면 비트반전된 값은 음수 임으로 입력한 정수와 비트 반전된 정수를 비교하면 입력한 정수가 양수인지 음수인지 알 수 있습니다.
# - (3) 0의 비트 반전된 결과는 -1임으로 정수로 0을 입력했을 때 조건문을 이용하여 0을 판별하였습니다.

# %% [markdown]
# ***
# # Problem 4

# %% [markdown]
# - 두 개의 리스트를 인자로 받아서 그 두 개의 리스트에 대한 '합집합'을 반환하는 함수 list_union(lista, listb)를 작성하시오.
#   - 인자로 전달하는 리스트 2 개에는 정수값만 들어간다고 가정하자.
#   - 함수 내에서 새로운 리스트를 만들어 그 리스트 내에 인자로 받은 두 리스트의 모든 원소를 넣어 반환한다.
#   - 반환하는 리스트에는 절대로 중복된 원소가 들어 있으면 안된다 (집합의 조건).
#   - 반환하는 리스트는 정렬이 되어 있어야 한다.
#   - 다음과 같은 실행 및 출력 결과가 도출되어야 한다.
#     - list_union([1, 2, 3], [1, 2, 4])
#       - [1, 2, 3, 4]
#     - list_union([-10, -5, 0, -1], [100, 9, 0, 9])
#       - [-10, -5, -1, 0, 9, 100]
#     - list_union([0, 1, 2], [0, 1, 2])
#       - [0, 1, 2]
#   - [참고] 리스트(l) 내에 새로운 정수값 (예를 들어 10)을 넣는 방법은 l.append(10) 이다.
#   - [참고] 임의의 정수값 (x)이 리스트 (l) 내에 존재하는지 판단하는 방법은 x in l 이다.
#   ***

# %%
# -*- coding: utf-8 -*-
def list_union(lista = [], listb = []): #합집합 구하는 함수 
    count = 0 #반복문용 변수1 
    count2 = 1 #반복문용 변수1
    temp = 0 #임시값용 변수 
    new_list = [] #합집합용 공백 리스트
    
    while count < len(lista): #lista의 원소를 new_list에 모두 추가 
        new_list.append(lista[count]) #lista 집합의 원소 추가 
        count = count + 1
    count = 0
    while count < len(listb): #listb의 원소를 new_list에 모두 추가
        new_list.append(listb[count]) #listb 집합의 원소 추가
        count = count + 1
    count = 0    #count 0으로 초기화 
        
    while count < len(new_list): #합집합 조건에 맞게 처리
        temp = count2 #new_list의 첫원소와 나머지 원소들을 비교
        while count2 < len(new_list):
            if new_list[count] == new_list[count2]:
                new_list.pop(count2) #중복되는 원소가 있으면 제거
            count2 = count2 + 1
        count2 = temp
        count2 = count2 + 1 #반복문 카운트 증가 
        count = count + 1   #반복문 카운트 증가      

    new_list.sort() #중복이 처리된 집합을 정렬 시킴 
    return new_list #중복 원소 제거 및 정렬된 합집합 반환 
        
        
union = list_union([1,2,3],[1,2,4])
union2 = list_union([-10,-5,0,-1],[100,9,0,9])
union3 = list_union([0,1,2],[0,1,2])

print 'list_union([1,2,3],[1,2,4]) : ',
print union
print 'list_union([-10,-5,0,-1],[100,9,0,9]) : ',
print union2
print 'list_union([0,1,2],[0,1,2]) : ',
print union3
# Out:
# list_union([1,2,3],[1,2,4]) :  [1, 2, 3, 4]
# list_union([-10,-5,0,-1],[100,9,0,9]) :  [-10, -5, -1, 0, 9, 100]
# list_union([0,1,2],[0,1,2]) :  [0, 1, 2]

# %% [markdown]
# 설명
#     - (1) 인자로 전달받은 두 개의 리스트안의 원소들을 모두 new_list인 새 리스트에 모두 append()를 이용하여 넣습니다.
#     - (2) 두개의 리스트가 합해진 new_list에서 첫원소부터 시작해서 첫 원소와 리스트 안에 있는 다른 원소들과 비교하여 같다는 것은 중복된 원소가 있다는 것이므로 pop()을 이용해서 중복된 원소를 제거했습니다.
#     - (3) 중복 원소가 제거된 new_list(합집합)을 sort()함수를 이용해서 리스트 안의 값을 오름차순으로 정렬시킨 후 최종 결과인 합집합 new_list를 반환하고 출력했습니다.
# ***

# %% [markdown]
# ***
# # Problem 5

# %% [markdown]
# - 경로에 해당하는 문자열 1개를 입력 받아 그 안에 디렉토리 경로명과 파일명을 분리하여 리스트로 반환하는 함수 div_path(s)를 작성하시오.
#   - 인자로 전달하는 문자열은 경로만 들어간다고 가정한다.
#   - 각 디렉토리와 파일을 구분하는 문자는 '/'로 가정한다.
#   - 반환하는 리스트의 첫번째 원소는 디렉토리이고 두번째 원소는 파일명이다.
#   - 다음과 같은 실행 및 출력 결과가 도출되어야 한다.
#     - div_path('/usr/local/bin/python')
#       - ['/usr/local/bin', 'python']
#     - div_path('/home/chulsoo/test.txt')
#       - ['/home/chulsoo', 'test.txt']
# ***

# %%
# -*- coding: utf-8 -*-
def div_path(s): #문자열 나누기 함수 
    local_name_list = [] #나눈 결과를 저장할 공백 리스트
    count = 0 
    x = 0 #반복문용 카운트 
    slice_count = 0 
    while x < len(s): 
        if s[x] == '/': #문자열 안에 '/'가 몇개 있는지 카운트 
            count = count + 1 
        x = x + 1 

    x = 0 #반복문 카운트 초기화 

    while x < count: #문자열 안의 '/' 이 문자 수만큼 반복
        if s[slice_count] == '/': #'/'문자가 나오면 카운트 증가 
            x = x + 1 
        slice_count = slice_count + 1 #마지막 '/'문자가 나올때 까지 카운트 

    local_name_list.append(s[:slice_count]) #경로명 리스트에 추가 
    local_name_list.append(s[slice_count : ]) #파일명 리스트에 추가 
    return local_name_list #결과 리스트 반환 

str_split = div_path('/usr/local/bin/python') 
str_split2 = div_path('/home/chulsoo/test.txt') 

print str_split 
print str_split2
# Out:
# ['/usr/local/bin/', 'python']
# ['/home/chulsoo/', 'test.txt']

# %% [markdown]
# 설명
#     - (1) 인자로 전달받은 리스트안에 '/'의 개수를 카운트 합니다.
#     - (2) 카운트한 '/'이 문자의 수만큼 반복문을 돌리면서 마지막 '/'문자가 나올때 까지 카운트를 합니다.
#     - (3) 그러면 마지막 '/'가 나올때까지의 문자열안의 인덱스가 slice_count에 저장이 되고 이것을 이용하여 Slice를 이용하면 s[:slice_count]는 경로명이 되고, s[slice_count : ]는 파일명이 됩니다. 이 둘을 새 리스트에 추가시겨서 반환하면 문제가 원하는 답이 출력됩니다.

# %% [markdown]
# ***
# # Problem 6

# %% [markdown]
# - 웹 URL로 지정된 웹페이지를 문자열로 가져와 1) 모든 HTML 태그 및 CSS와 Javascript를 제외한 순수 텍스트만을 출력하고, 2) 그 순수 텍스트 안에 존재하는 단어가 총 몇개인지 출력하는 프로그램을 작성하시오.
#   - HTML 태그는 다음 조건을 가지는 것이다.
#     - < 로 시작하여 >로 끝나거나 />로 끝난다.
#     - </ 로 시작하여 > 로 끝난다.
#   - HTML 문서 내에 존재하는 CSS 삭제시 참고할 사항
#     - &lt;style&gt; 혹은 &lt;STYLE&gt;로 시작한다.
#     - &lt;/style&gt; 혹은 &lt;/STYLE&gt;로 끝난다.
#     - &lt;style&gt; (혹은 &lt;STYLE&gt;)과 &lt;/style&gt; (혹은 &lt;/STYLE&gt;) 내에 존재하는 CSS 코드는 모두 삭제한다.
#   - HTML 문서 내에 존재하는 Javascript 삭제시 참고할 사항
#     - &lt;script&gt; 혹은 &lt;SCRIPT&gt;로 시작한다.
#     - &lt;/script&gt; 혹은 &lt;/SCRIPT&gt;로 끝난다.
#     - &lt;script&gt; (혹은 &lt;SCRIPT&gt;)과 &lt;/script&gt; (혹은 &lt;/SCRIPT&gt;) 내에 존재하는 Javascript 코드는 모두 삭제한다.
#   - 즉, CSS 코드와 Javascript 코드는 단어의 총수를 카운트 할 때 고려하지 않는다.
#   - 한편, 다음은 URL로 지정된 웹페이지를 특정 문자열로 가져오는 코드이다.
# ***

# %%
# -*- coding: utf-8 -*-
import urllib
s = urllib.urlopen('http://www.kut.ac.kr/').read()
s = s.splitlines()


def filter(site):
    count = 0
    temp = []
    while count < len(site):
        temp = s[count]
        temp = temp.strip()
        site[count] = temp
        count = count + 1

    count = 0
    while count < len(site):
        temp = count
        if site[count] == '':
            del site[count]
            count = temp
        else:
            count += 1 
    return site        


def DelScriptandCSS(site):
    index = 0
    while index < len(site):           
        if site[index].startswith('<script') or site[index].endswith('</script>') or site[index].startswith('<SCRIPT') or site[index].endswith('</SCRIPT>'):
            del site[index]
            while index < len(site):
                if site[index].endswith('</script>') or site[index].endswith('</SCRIPT>'):
                    site[index] = ''
                    break
                elif site[index].startswith('<'):
                    break  
                else:
                    del site[index]
        index += 1
    #------------------------
    index = 0
    while index < len(site):           
        if site[index].startswith('<style') or site[index].endswith('</style>') or site[index].startswith('<STYLE') or site[index].endswith('</STYLE>'):
            del site[index]
            while index < len(site):
                if site[index].endswith('</style>') or site[index].endswith('</STYLE>'):
                    site[index] = ''
                    break
                elif site[index].startswith('<'):
                    break  
                else:
                    del site[index]
        index += 1    
    return site      

s = filter(s)
s = DelScriptandCSS(s)



flag = 0
count = 0
while count < len(s):
    temp = ''
    index = 0
    sample = s[count]
    for index in sample:
        if index == '<':
            flag = 1
        if flag == 1 and index != '>':
            continue
        elif flag == 1 and index == '>':     
            flag = 0
        if flag == 0 and index != '>':
            temp += index
    print temp
    count += 1
# Out:
# 한국기술교육대학교 홈페이지
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  주요메뉴 바로가기 본문 바로가기 하단메뉴 바로가기
#
#
#
#
#
#
# 현재 스크립트가 꺼져 있는 상태입니다.
# 스크립트를 사용하지 않으시면 홈페이지 이용에 불편사항이 있습니다.
# 스크립트 사용을 권장합니다.
#
# KOREATECH 한국기술교육대학교
#
#
# 탑 유틸메뉴
# HOME
# LOGIN
# WEBMAIL
# SITEMAP
# ENGLISH
# CHINESE
# 통합검색 입력폼
# facebookdaumnaveryoutube
#
#
#
#  대학소개
#
# 대학소개
#  대학소개 대한민국 기술리더 KOREATECH 세계를 품다!
#
#
#
# KOREATECH소개
# 총장실
# 대학현황
# VISION2020
#
#
#
#
# KOREATECH20년
# 대학조직
# 국제교류
# 사이버감사실
#
#
#
#
# KOREATECH발전기금
#
#
#
#
#
#
#
#  입학안내
#
# 입학안내
#  입학안내 학생이 행복한 대학 KOREATECH 학생중심! 교육중심!
#
#
#
# 대학
# 대학원
#
#
#
#
#
#
#
#  대학/대학원
#
# 대학/대학원
#  대학/대학원 기업이 신뢰하는 대학  KOREATECH 교육중심 1위 대학
#
#
#
# 대학
# 대학원
#
#
#
#
#
#
#
#  대학생활
#
# 대학생활
#  대학생활 대한민국의 미래를 선도하는 행복대학 KOREATECH
#
#
#
# 학사안내
# 해외연수
# 장학제도
# 캠퍼스생활
#
#
#
#
# 병사안내
#
#
#
#
#
#
#
#  커뮤니티
#
# 커뮤니티
#  커뮤니티  도전! 열정! 창의! 재학생 만족도 1위, 취업률 1위 KOREATECH
#
#
#
# 공지사항
# 참여게시판
# 자료실
# 설문조사
#
#
#
#
# 휴먼아카데미(명사특강)
# 취업역량강화(동영상)
# 학부모님 의견란
#
#
#
#
#
#
#
#  대학홍보
#
# 대학홍보
#  대학홍보 대학민국 NO.1 교육중심대학 KOREATECH
#
#
#
# KOREATECH NEWS
# 홍보영상물
# KOREATECH 홍보대사
# 캠퍼스사진
#
#
#
#
# 언론보도모음집
# 대학소식지
# 사이버투어
# 캠퍼스투어
#
#
#
#
# 홍보브로셔
#
#
#
#
#
#
#
#  정보공개
#
# 정보공개
#  정보공개 투명한 학교운영 교육중심대학 KOREATECH
#
#
#
# 정보공개
# 공공데이터개방
# 행정공시
#
#
#
#
#
#
#
#
#
#
#
# KOREATECH 한국기술교육대학교
#
#
#
#
#
# 대학소개
#
# KOREATECH소개
# 총장실
# 대학현황
# VISION2020
# KOREATECH20년
# 대학조직
# 국제교류
# 사이버감사실
# KOREATECH발전기금
#
#
#
# 입학안내
#
# 대학
# 대학원
#
#
#
# 대학/대학원
#
# 대학
# 대학원
#
#
#
# 대학생활
#
# 학사안내
# 해외연수
# 장학제도
# 캠퍼스생활
# 병사안내
#
#
#
# 커뮤니티
#
# 공지사항
# 참여게시판
# 자료실
# 설문조사
# 휴먼아카데미(명사특강)
# 취업역량강화(동영상)
# 학부모님 의견란
#
#
#
# 대학홍보
#
# KOREATECH NEWS
# 홍보영상물
# KOREATECH 홍보대사
# 캠퍼스사진
# 언론보도모음집
# 대학소식지
# 사이버투어
# 캠퍼스투어
# 홍보브로셔
#
#
#
# 정보공개
#
# 정보공개
# 공공데이터개방
# 행정공시
#
#
#
#
#
#
# 통합검색 입력폼
#
# --
#
# 탑 유틸메뉴
# LOGIN
# WEBMAIL
# SITEMAP
# ENGLISH
# CHINESE
#
# facebookdaumnaveryoutube
#
#
#
#
#
#
#
#
#
#
#
#
# 이전
#
#
#
#
#
#
#
# --
#
#
# 다음
#
# 팝업닫기
#
# 팝업열기
#
#
#
#
#
#
#
#
# PEOPLE
#
#
#
# 재학생
#
#
# 온라인교육지원
# 생활관
# 교내인증 S/W
# 무선랜신청
# 원격지원
# 오늘의 식단
# 시설보수신청
# 학사종합서비스
# 인터넷증명발급
# 시설물신청
# 동아리안내
# IPP센터
#
#
# 예비대학생
#
#
# 입학안내
# 학부소개
# 캠퍼스투어
# 찾아오시는길
# 생활관
# 국제교육센터
# 해외연수
# 장학제도
# 전화번호찾기
# NEWS
# 홍보영상물
# 캠퍼스사진
#
#
# 교직원
#
#
# 아우누리
# 온라인교육지원
# 생활관
# 교내인증 S/W
# 무선랜신청
# 원격지원
# 오늘의 식단
# 시설보수신청
# 인터넷증명발급
# 전자출결(RFID)
# 학교차량신청
# 교육장비검색
#
#
# 동문인
#
#
# 온라인교육지원
# 생활관
# 교내인증 S/W
# 무선랜신청
# 원격지원
# 오늘의 식단
# 시설보수신청
# 인터넷증명발급
# 총동문회
# 한기대발전기금
# 능력개발교육원
#
#
#
#
# 닫기
#
#
#
#
# BUS
#
#
#
#
#
#
# 학생이 만족하는 대학 사실에 근거하여 진리를 탐구하는 현장중심과 실험실습을 강조하는 KOREATECH
#
# 1
#
# 1
# 2
# 3
# 4
# --
# 재생
# 정지
#
#
#
#
#
#
#
#
# --
#
#
#
#
#
# 학생이 만족하는 대학 사실에 근거하여 진리를 탐구하는 현장중심과 실험실습을 강조하는 KOREATECH
# 이전
#
#
#
#
#
# 다음
#
#
#
#
# 학생이 만족하는 대학 사실에 근거하여 진리를 탐구하는 현장중심과 실험실습을 강조하는 KOREATECH
#
# 1
# 2
# 3
# 4
# 재생
# 정지
#
#
#
#
#
#
#
#
# //데스크탑 & 태블릿 비주얼 --
#
#
# 학생이 만족하는 대학 사실에 근거하여 진리를 탐구하는 현장중심과 실험실습을 강조하는 KOREATECH
# 이전
#
#
#
#
#
#
#
#
# 다음
#
# //모바일 비주얼 --
#
#
#
#
#
#
#
#
# 일반공지
#
#
# 한국기술교육대학교 총장 초빙공고
# [LINC] 제3회 가족회사의 날 개최 알림
# [추가개설]9월 다섯째주 취업클리닉 운영 안내
# 2015학년도 1학기 IPP 프로그램 설명회 개최 안내
# 학사경고를 받은 학생들을 위한 상담 안내
#
#
#
# [네트워크] 긴급 패치 작업으로 인한 서비스안내 [네트워크] 긴급 패치 작업으로 인한 서비스안내 [네트워크] 긴급 패치 작업으로 인한 서비스안내
# [IPP센터] 제3기 KOTRA IPP 설명회 안내
# [IPP센터] 2014학년도 상반기 IPP 신청 안내[IPP센터] 2014학년도 상반기 IPP 신청 안내
# [KOREATECH 인문향연] 인디밴드 콘서트 'THE ...
# [현장실습] 동계 인턴 및 HRD 현장실습 설명회 개최...
# 우리말 뽐내기 준비를 위한 글쓰기 특강 안내
#
# --
# 더보기
#
# 장학공지
#
#
# 재학중우수자]2014년도 국가우수장학금(이공계) 재학중...
# 희망사다리장학]2014-2학기 중소기업 취업전제 희망사...
# 가구원 사전동의]2015-1학기 달라지는 학자금지원 '...
# [학기근로봉사]2014-2학기근로봉사장학생 선발명단 공...
# 고속도로장학재단]2014년 고속도로 장학금 지급(신청)...
#
# 더보기
#
# 취업공지
#
#
# AhnLab QA연수생 모집
# 대방건설(주) 채용공고
# 단암시스템즈 신입 및 경력 모집
# 세메스(중국법인) 반도체 설비 엔지니어 채용공고
# 한국기계연구원 채용공고
#
# 더보기
#
#
#
#
#
# 더보기
# 더보기
#
#
#
#
#
#
#
#
#
#
#
# KOREATECH NEWS
#
#
# 한국기술교육대 메카트로닉스공학부 김광선 교수 (사)한국...
# 한국기술교육대 LINC사업단 ＇가족회사 자문단＇ 운영
# 김동연 전 국무조정실장의 ‘꿈과 도전’
# ‘2014 전국 대학생 하이브리드 자동차 경진대회＇ 개...
# LINC사업단, 장비활용 및 도입으로 기업지원 확대
#
# 더보기
#
#
#
#
#
#
#
#
#
#
# 팝업존
#
#
# 145
#
# 1
#
# 2
#
# --
#
# 정지 플레이
#
#
#
#
#
#
#
# UNIVERSITY OF KOREATECH Cyber Tour
#
#
#
#
#
#
#
#
# 자주찾는 서비스
# 학사종합서비스
# 온라인교육
# 인터넷증명발급
# 학사일정
# 발전기금
# 도서관이용안내
# 학과안내
# 수강신청
#
#
#
#
# 자주찾는 서비스
#
#
#
# 자주찾는 서비스
#
#
# 학사종합서비스
# 온라인교육
# 인터넷증명발급
# 학사일정
# 발전기금
# 도서관이용안내
# 학과안내
# 수강신청
#
#
#
#
# 닫기
#
#
#
# People
#
#
#
# 재학생
#
#
# 온라인교육지원
# 생활관
# 교내인증 S/W
# 무선랜신청
# 원격지원
# 오늘의 식단
# 시설보수신청
# 학사종합서비스
# 인터넷증명발급
# 시설물신청
# 동아리안내
# IPP센터
#
#
# 예비대학생
#
#
# 입학안내
# 학부소개
# 캠퍼스투어
# 찾아오시는길
# 생활관
# 국제교육센터
# 해외연수
# 장학제도
# 전화번호찾기
# NEWS
# 홍보영상물
# 캠퍼스사진
#
#
# 교직원
#
#
# 아우누리
# 온라인교육지원
# 생활관
# 교내인증 S/W
# 무선랜신청
# 원격지원
# 오늘의 식단
# 시설보수신청
# 인터넷증명발급
# 전자출결(RFID)
# 학교차량신청
# 교육장비검색
#
#
# 동문인
#
#
# 온라인교육지원
# 생활관
# 교내인증 S/W
# 무선랜신청
# 원격지원
# 오늘의 식단
# 시설보수신청
# 인터넷증명발급
# 총동문회
# 한기대발전기금
# 능력개발교육원
#
#
#
#
# 닫기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 관련사이트
#
#
# 대학/대학원
#
# 대학/대학원
# 기계공학부
# 메카트로닉스공학부
# 전기전자통신공학부
# 컴퓨터공학부
# 디자인공학과
# 건축공학부
# 에너지신소재화학공학부
# 산업경영학부
# 교양학부
# 메카IT융합공학과
# 일반대학원
# 테크노인력개발전문대학원
# IT융합과학경영대학원
# 최고경영자과정
#
#
#
#
# 주요사이트
#
# 주요사이트
# 다음 공식카페
# 학사종합서비스
# 온라인교육지원
# 웹갤러리
# 동문홈페이지
# 웹메일
# 고용부 잡영
# 고용부 워크넷
# 잡코리아
# 사람인
# 인크루트
#
#
#
#
# 교내주요기관
#
# 교내주요기관
# 고용노동연수원
# 능력개발교육원
# 다산정보관
# 첨단훈련매체개발센터
# 산학협력단
# LINC사업단
# 생활협동조합
# 생활관
# 국제교육센터
# 공학교육혁신센터
# MOT사업단
# 반도체장비교육센터
# 개도국기술이전연구소
# HRD연구센터
# 대학교육개발센터
# 상담진로개발센터
# IPP센터
# PSM사업단
# CIGMA CENTER
#
#
#
#
# 학생자치단체
#
# 학생자치단체
# 총학생회
# 총여학생회
# 총동아리연합회
# 한기대방송국
# 한기대신문사
# 교지편집위원회
# 생활관자치회
# 전국대학생하이브리드자동차경진대회
# 졸준위-08
# 졸준위-07
#
#
#
#
# 대외유관기관
#
# 대외유관기관
# 고용노동부
# 지식경제부
# 기획재정부
# 한국산업인력공단
# 한국폴리텍대학
# 한국교육개발원
# 한국노동연구원
# 근로복지공단
# 한국산업안전보건공단
# 한국고용정보원
# 한국직업능력개발원
# 장애인고용공단
# 충청남도청
# 천안시청
# 국민권익위원회
# 교육과학기술부
# NTIS
# 원격훈련심사센터
#
#
#
#
# Footer link
#
# Footer link
# 개인정보처리방침
# 이메일무단수집거부
# 윤리헌장
# 행정서비스헌장
# 알리오
# 대학정보공시
# 공학교육인증안내
# 도로명주소안내
#
#
#
#
#
#
#
#
# 개인정보처리방침
# 이메일무단수집거부
# 윤리헌장
# 행정서비스헌장
# 알리오
# 대학정보공시
# 공학교육혁신센터
# 도로명주소안내
#
# (330-708) 충남 천안시 동남구 병천면 충절로 1600 (가전리 307)&nbsp;&nbsp;&nbsp;Tel. 041-560-1114
# Copyrightⓒ2014 KOREATECH. All rights reserved.

# %% [markdown]
# - 설명 :
# ***

# %% [markdown]
# ***
# 소감 :
